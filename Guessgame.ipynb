# %%
def check_mate(rword): 
    guesses = ';' 
    turn = 4                                                # No of chances a user can input wrong letter/word
    while(turn>0):
        fail = 0                                            # wrong input counter
        for char in rword: 
            if char in guesses:
                print(char)   
            else:
                print("_") 
                fail += 1
       
        if fail == 0:
            print("Great Saiyan!!!,You might go one on one with Goku...\n..................Someday\n\n For now............ You Win")
            break    
            
        guess = input("Enter your guess: ")
        guesses +=guess
     
  # Alarming player about his remaining attempts to be wrong

        if guess not in rword:
            turn -=1
            if  turn>0:
                print("Careful,You can make mistakes only {} times".format(turn))
            
        
            if turn == 0:                                           # End of chances to attempt // Game Over
                print("How pity!! Defeated by Yamcha\n.............HAKAAAAAIIIIII............." )
    
# To be used if input is from a text file
    
#def choose_random():
    #import random
    #l = list()              
    #f = open("Words.txt","r")
    #for words in f:
        #l.append(words)
    #return random.choice(l)
    #f.close()

# Welcome Note and rules 

print('''                                       Welcome to the word of DBZ!!!! 
                                    let's test your loyality towards US
                 Guess the word from DBZ and prove you worth or else you would be Hakai''')

name = input("\nWelcome Saiyan!!!! What's your name:) ") #Taking player's name
print("Hey {},Remember all letters should lowercase\nWord to guess could be character name attack name or transormation name from DBZ\nYou can guess the whole word or a letter at a time\nYou could be wrong only for 4 times\n\n".format(name))

# Picking a random word
import random
word = ['akura','sakura','vegeta','kame','hermit','goku','kakkarot']
rword = random.choice(word)

#rword = choose_random()  #To be used when taking input through any text file
#print (rword) # Shows random word only for checking purpose 

check_mate(rword) # Calling the evaluating function
# Out:
#                                        Welcome to the word of DBZ!!!!
#                                     let's test your loyality towards US
#                  Guess the word from DBZ and prove you worth or else you would be Hakai
#
# Welcome Saiyan!!!! What's your name:) l
# Hey l,Remember all letters should lowercase
# Word to guess could be character name attack name or transormation name from DBZ
# You can guess the whole word or a letter at a time
# You could be wrong only for 4 times
#
#
# _
# _
# _
# _
# _
# _
# Enter your guess: a
# _
# a
# _
# _
# _
# a
# Enter your guess: k
# _
# a
# k
# _
# _
# a
# Enter your guess: u
# _
# a
# k
# u
# _
# a
# Enter your guess: r
# _
# a
# k
# u
# r
# a
# Enter your guess: a
# _
# a
# k
# u
# r
# a
# Enter your guess: s
# s
# a
# k
# u
# r
# a
# Great Saiyan!!!,You might go one on one with Goku...
# ..................Someday
#
#  For now............ You Win
